# %% [markdown]
# ## Generate word2vec embeddings using TensorFlow
#
# Use Noise Contrastive Estimator (NCE) as a loss function
#
# Modified from original code here: http://adventuresinmachinelearning.com/word2vec-tutorial-tensorflow/

# %% [markdown]
# #### Some imports to make code compatible with Python 2 as well as 3

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
import collections
import math
import os
import random
import zipfile

# %%
from six.moves import urllib
from six.moves import xrange

# %%
import numpy as np
import tensorflow as tf

# %%
print(np.__version__)
print(tf.__version__)
# Out:
# 1.13.1
# 1.3.0

# %%
DOWNLOADED_FILENAME = 'SampleText.zip'

def maybe_download(url_path, expected_bytes):
    if not os.path.exists(DOWNLOADED_FILENAME):
        filename, _ = urllib.request.urlretrieve(url_path, DOWNLOADED_FILENAME)
    statinfo = os.stat(DOWNLOADED_FILENAME)

    if statinfo.st_size == expected_bytes:
        print('Found and verified file from this path: ', url_path)
        print('Downloaded file: ', DOWNLOADED_FILENAME)
    else:
        print(statinfo.st_size)

        raise Exception(
            'Failed to verify file from: ' + url_path + '. Can you get to it with a browser?')

# %%
def read_words():
    with zipfile.ZipFile(DOWNLOADED_FILENAME) as f:
        firstfile = f.namelist()[0]
        filestring = tf.compat.as_str(f.read(firstfile))
        words = filestring.split()
    
    return words

# %%
URL_PATH = 'http://mattmahoney.net/dc/text8.zip'
FILESIZE = 31344016

maybe_download(URL_PATH, FILESIZE)
# Out:
# Found and verified file from this path:  http://mattmahoney.net/dc/text8.zip
# Downloaded file:  SampleText.zip

# %% [markdown]
# #### Get the list of words from the the sample, this is our entire vocabulary

# %%
vocabulary = read_words()

# %%
len(vocabulary)
# Out:
# 17005207

# %%
vocabulary[:25]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes']

# %% [markdown]
# ### Build the data set used to generate word2vec embeddings
#
# * *words* A list of all words in the input dataset
# * *n_words* The number of words to include in the dataset. We use the most frequently occurring n_words
#
# Return values are:
#
# * *word_counts* The most frequently occurring words and the corresponding frequencies
# * *word_indexes* The list of index values which uniquely identifies each word in the dataset
# * *dictionary* Mapping from a word to its unique index
# * *reversed_dictionary* Mapping from the unique index to the word

# %%
def build_dataset(words, n_words):
    word_counts = [['UNKNOWN', -1]]
    
    counter = collections.Counter(words)
    word_counts.extend(counter.most_common(n_words - 1))
 
    # Only the most common words are added to the dictionary
    dictionary = dict()
    
    for word, _ in word_counts:
        # The current length of the dictionary is the unique index of this word
        # added to the dictionary
        dictionary[word] = len(dictionary)
    
    word_indexes = list()
    
    unknown_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNKNOWN']
            unknown_count += 1
        
        word_indexes.append(index)
    
    # Count of unknown words
    word_counts[0][1] = unknown_count
    
    # Map from unique indexes to word
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return  word_counts, word_indexes, dictionary, reversed_dictionary

# %%
VOCABULARY_SIZE = 100000

word_counts, word_indexes, dictionary, reversed_dictionary = build_dataset(vocabulary, VOCABULARY_SIZE)

# %%
word_counts[:10]
# Out:
# [['UNKNOWN', 189230],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
word_indexes[:10]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
for key in random.sample(dictionary, 10):
    print(key, ":", dictionary[key])
# Out:
# scone : 43809
# honeycombs : 73949
# heavy : 1007
# suicidal : 15878
# renders : 15667
# operaci : 78591
# reuven : 46731
# farringdon : 65855
# vegemite : 74518
# milking : 48369

# %%
for key in random.sample(reversed_dictionary, 10):
    print(key, ":", reversed_dictionary[key])
# Out:
# 83629 : centroamericana
# 32850 : romani
# 14900 : zoroastrianism
# 38674 : galahad
# 96689 : scagliola
# 60844 : sobers
# 34655 : montaigne
# 35856 : presumptive
# 82305 : videodrome
# 93606 : nonmagnetic

# %% [markdown]
# #### A hint to the Python interpreter that vocabulary can be deleted

# %%
del vocabulary

# %% [markdown]
# ### Return one batch of data and the corresponding labels for training
#
# * *word_indexes* A list of unique indexes which identifies each word in the dataset. The most popular words have the lowest index values
# * *batch_size* The number of elements in each batch
# * *num_skips* The number of words to choose from the neighboring words within the skip_window. Each input word will appear num_skips times in the batch with a context or neighboring word as the corresponding label
# * *skip_window* How many words to consider around one input word

# %%
# Global index into words maintained across batches
global_index = 0

def generate_batch(word_indexes, batch_size, num_skips, skip_window):
    global global_index

    # For every input we find num_skips context words within a window
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    # batch = [1, 2, 3, .... batch_size]
    # labels = [[1], [2], [3], ..., [batch_size]]
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    # The span of a window includes the skip_window elements on each side
    # of the input word plus the word itself
    span = 2 * skip_window + 1  # [ skip_window input_word skip_window ]

    # A deque is double-ended queue which supports memory efficient appends
    # and pops from each side
    buffer = collections.deque(maxlen=span)

    # Initialize the deque with the first words in the deque
    for _ in range(span):
        buffer.append(word_indexes[global_index])
        global_index = (global_index + 1) % len(word_indexes)
    
    for i in range(batch_size // num_skips):
        target = skip_window  # input word at the center of the buffer
        targets_to_avoid = [skip_window]

        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            
            batch[i * num_skips + j] = buffer[skip_window]  # this is the input word
            labels[i * num_skips + j, 0] = buffer[target]  # these are the context words
        
        # The first word from the buffer is removed automatically when a new word
        # is added in at the end
        buffer.append(word_indexes[global_index])
        global_index = (global_index + 1) % len(word_indexes)
    
    # Backtrack a little bit to avoid skipping words in the end of a batch, these
    # words will be captured in the next batch
    global_index = (global_index + len(word_indexes) - span) % len(word_indexes)

    return batch, labels

# %%
batch, labels = generate_batch(word_indexes, 10, 2, 5)

# %%
batch
# Out:
# array([   2,    2, 3137, 3137,   46,   46,   59,   59,  156,  156], dtype=int32)

# %%
labels
# Out:
# array([[  59],
#        [5239],
#        [   6],
#        [   2],
#        [   2],
#        [ 128],
#        [ 195],
#        [ 477],
#        [ 134],
#        [3137]], dtype=int32)

# %%
for i in range(9):
    print(reversed_dictionary[batch[i]], ": ", reversed_dictionary[labels[i][0]])
# Out:
# of :  used
# of :  anarchism
# abuse :  a
# abuse :  of
# first :  of
# first :  early
# used :  term
# used :  class
# against :  including

# %% [markdown]
# ### Initialize some variables to build and train the skip-gram model
#
# * *batch_size*: The size of the batch to use in training
# * *embedding_size*: Dimensions of the embedding vector i.e. how many features we use to represent a word
# * *skip_window*: How many words to include in the context, this is to the left and right
# * *num_skips*: How many context words to associate with each target word

# %%
batch_size = 128
embedding_size = 50
skip_window = 2
num_skips = 2

# Reset the global index because we updated while testing the batch code
global_index = 0

# %% [markdown]
# ### Choose some words at random to validate our trained model
#
# * *valid_size*: Number of words to evaluate our model, we'll use these words to see how similar the closest words are
# * *valid_window*: The window from where we draw the words to run validation on, only pick from the most commonly used words
#
# Choose the set of words from the top 100 at random

# %%
valid_size = 16  
valid_window = 100

valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %% [markdown]
# ### Number of negative examples to sample for NCE loss calculation

# %%
num_samples = 64

# %% [markdown]
# ### Input placeholder to feed data in batches

# %%
tf.reset_default_graph()

train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])

# %% [markdown]
# ### Set up a constant to hold validation data

# %%
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %% [markdown]
# ### Embeddings are word representations that will be generated by word2vec
#
# Initialize a variable to hold the embeddings and embeddings for specific words can be accessed using *tf.nn.embedding_lookup*
#
# NOTE: Embeddings and NCE losses only work on the CPU in TensorFlow, GPU support has not been added yet

# %%
embeddings = tf.Variable(
    tf.random_uniform([VOCABULARY_SIZE, embedding_size], -1.0, 1.0))
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# %% [markdown]
# ### Construct weights and biases to hold the NCE (Noise Contrastive Estimation) loss

# %%
nce_weights = tf.Variable(
    tf.truncated_normal([VOCABULARY_SIZE, embedding_size],
                        stddev=1.0 / math.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([VOCABULARY_SIZE]))

# %%
loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_samples,
                     num_classes=VOCABULARY_SIZE))

# %%
 optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# %% [markdown]
# ### Normalize the embeddings vector to calculate cosine similarity between words
#
# *normalized_vector = vector / L2 norm of vector*

# %%
l2_norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / l2_norm

# %% [markdown]
# #### Look up the normalized embeddings of the words we use to validate our model

# %%
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)

# %% [markdown]
# #### Find the cosine similarity of the validation words against all words in our vocabulary

# %%
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
init = tf.global_variables_initializer()

# %%
num_steps = 200001

# %%
final_embeddings = None

with tf.Session() as session:
    init.run()

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            word_indexes, batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 20000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reversed_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reversed_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
            print("\n")
            
    final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step  0 :  290.191711426
# Nearest to called: ptfe, sabina, accessible, broadleaf, lennier, cometary, uss, atx,
# Nearest to who: protested, unionism, risk, mackey, tripos, preternatural, tenet, licensees,
# Nearest to system: vittorini, proteases, cloud, beautiful, pyroclastic, freemen, jyllands, cno,
# Nearest to the: guidebook, leipzig, gennifer, scalable, bergson, francione, macmanus, sitia,
# Nearest to would: migr, waterhouse, aerodynamically, azerbaijani, contributor, satires, beadwork, forbade,
# Nearest to use: better, engin, punto, propounds, lawyers, mahipala, nonhumans, basset,
# Nearest to so: aharon, eplf, swieten, theotokos, nehuniah, chant, jess, enrolled,
# Nearest to however: shanks, beeching, droit, qabala, maroc, adkisson, incognito, lanthanides,
# Nearest to six: yore, natriuretic, simulator, champaran, pleading, betelgeuse, druid, rpm,
# Nearest to been: dhrystone, cultivators, thibert, evangelise, hue, decompressor, sixteenth, unrealistic,
# Nearest to are: nucleation, evocative, cursive, balthasar, beef, commemoration, mallon, weingartner,
# Nearest to some: oxides, gooey, sunday, packs, trajkovski, dutt, sketchbooks, scanners,
# Nearest to it: arithm, erasure, booting, alderson, proselytes, populi, athelney, samad,
# Nearest to had: spam, novosti, conservatively, inequality, unscr, castrated, horde, gujarat,
# Nearest to also: othmar, barged, hlhausen, antinomianism, quantized, dztwo, orsi, gunung,
# Nearest to b: abaye, glucoses, escapade, transcends, prozess, namath, mccready, paralyse,
#
#
# Average loss at step  2000 :  150.045711094
# Average loss at step  4000 :  85.4973634624
# Average loss at step  6000 :  61.4601082554
# Average loss at step  8000 :  48.3714734459
# Average loss at step  10000 :  39.6608269928
# Average loss at step  12000 :  32.3892554119
# Average loss at step  14000 :  27.8186737356
# Average loss at step  16000 :  23.5415665317
# Average loss at step  18000 :  20.2283260299
# Average loss at step  20000 :  18.4003139858
# Nearest to called: canaris, uss, accessible, abraxas, training, silk, classification, epistles,
# Nearest to who: their, unionism, fixed, better, unit, reddish, published, that,
# Nearest to system: beautiful, cloud, marple, agouti, fans, csa, complaints, partners,
# Nearest to the: a, his, an, and, ngc, its, cited, victoriae,
# Nearest to would: abort, spidey, sports, camp, preservation, live, they, risc,
# Nearest to use: better, newly, apache, agouti, reginae, albuquerque, hakama, traditionally,
# Nearest to so: montferrat, chant, straight, arms, yeast, geographic, ppp, mosque,
# Nearest to however: pollution, launched, needling, tyre, cumbersome, boundary, meridians, operatorname,
# Nearest to six: five, four, nine, eight, three, zero, seven, agouti,
# Nearest to been: plasma, pas, indicate, not, dwarfs, paddy, sidewise, no,
# Nearest to are: is, were, complained, aurelian, grown, associativity, numerous, depths,
# Nearest to some: many, sunday, his, proportion, although, unaided, success, ash,
# Nearest to it: never, more, he, queen, that, what, tasked, convey,
# Nearest to had: has, vertices, spam, rebuilt, discussing, churchill, abgar, anaconda,
# Nearest to also: knee, though, but, tenure, belt, for, which, grown,
# Nearest to b: e, fired, outputting, roddick, practically, rand, arc, appropriate,
#
#
# Average loss at step  22000 :  15.4626480602
# Average loss at step  24000 :  14.3524045064
# Average loss at step  26000 :  13.855972342
# Average loss at step  28000 :  12.5992227708
# Average loss at step  30000 :  11.3495233611
# Average loss at step  32000 :  10.6198396136
# Average loss at step  34000 :  9.53485673141
# Average loss at step  36000 :  9.67890098405
# Average loss at step  38000 :  8.8561631211
# Average loss at step  40000 :  8.4041121949
# Nearest to called: canaris, accessible, uss, abraxas, training, metric, himself, explicit,
# Nearest to who: which, better, he, fixed, unionism, that, their, they,
# Nearest to system: beautiful, cloud, marple, agouti, csa, interceptor, complaints, ocular,
# Nearest to the: an, a, its, their, this, which, ous, abet,
# Nearest to would: to, cpc, should, must, may, could, they, had,
# Nearest to use: better, agouti, newly, reginae, peanut, albuquerque, apache, traditionally,
# Nearest to so: montferrat, if, ppp, poe, hurrians, should, aelianus, yeast,
# Nearest to however: alectryon, tyre, adenylate, incapacitated, cumbersome, pond, jumna, agouti,
# Nearest to six: five, four, three, eight, seven, zero, one, nine,
# Nearest to been: paddy, pas, sidewise, reared, no, plasma, compass, midland,
# Nearest to are: were, is, complained, aurelian, though, or, nicaragua, muslim,
# Nearest to some: many, all, although, the, each, elmo, proportion, sunday,
# Nearest to it: which, this, he, that, but, what, appomattox, never,
# Nearest to had: has, have, was, vertices, glomerulosa, but, condensed, would,
# Nearest to also: knee, which, if, though, termed, now, and, tenure,
# Nearest to b: e, d, practically, female, fired, corner, outputting, rid,
#
#
# Average loss at step  42000 :  8.40820407915
# Average loss at step  44000 :  7.43770690608
# Average loss at step  46000 :  7.66475202489
# Average loss at step  48000 :  7.54158373296
# Average loss at step  50000 :  6.86139810514
# Average loss at step  52000 :  6.92710084069
# Average loss at step  54000 :  7.25282257497
# Average loss at step  56000 :  6.90254590201
# Average loss at step  58000 :  6.75578568602
# Average loss at step  60000 :  6.49559443736
# Nearest to called: canaris, makhuwa, pasternak, accessible, metric, barri, training, marek,
# Nearest to who: which, better, he, they, closer, photograph, by, himself,
# Nearest to system: beautiful, cloud, agouti, turnips, marple, while, interceptor, ursus,
# Nearest to the: its, an, a, their, another, abet, ursus, his,
# Nearest to would: will, could, may, should, to, must, can, had,
# Nearest to use: agouti, ffffcc, newly, reginae, prat, better, albuquerque, ocasio,
# Nearest to so: if, montferrat, burnley, haiti, hurrians, poe, yakovlev, aelianus,
# Nearest to however: barri, wct, where, pulau, alectryon, while, tyre, but,
# Nearest to six: five, four, eight, seven, three, nine, zero, agouti,
# Nearest to been: reticulum, sidewise, pas, reared, paddy, baghdad, ionizing, spoken,
# Nearest to are: were, martians, complained, is, though, nicaragua, bonzos, or,
# Nearest to some: many, all, each, other, these, several, although, different,
# Nearest to it: this, which, he, what, but, only, that, appomattox,
# Nearest to had: has, have, vertices, but, condensed, thus, would, was,
# Nearest to also: knee, which, now, if, obadiah, termed, ergosphere, warn,
# Nearest to b: d, e, UNKNOWN, rid, fired, r, practically, outputting,
#
#
# Average loss at step  62000 :  6.60825898242
# Average loss at step  64000 :  6.35410650057
# Average loss at step  66000 :  5.97798410702
# Average loss at step  68000 :  6.51918805289
# Average loss at step  70000 :  6.32089538133
# Average loss at step  72000 :  6.07215293443
# Average loss at step  74000 :  5.98274990499
# Average loss at step  76000 :  5.90070634079
# Average loss at step  78000 :  6.24148862022
# Average loss at step  80000 :  6.31464329326
# Nearest to called: microcebus, canaris, metric, praha, UNKNOWN, marek, megabats, makhuwa,
# Nearest to who: he, which, photograph, himself, by, closer, they, working,
# Nearest to system: beautiful, cno, agouti, interceptor, cloud, while, turnips, csa,
# Nearest to the: its, a, their, his, cebus, each, negating, fachhochschule,
# Nearest to would: will, may, could, should, must, can, to, thus,
# Nearest to use: reginae, agouti, prat, fachhochschule, newly, ffffcc, albuquerque, ocasio,
# Nearest to so: if, gly, hurrians, montferrat, poe, agouti, aelianus, when,
# Nearest to however: where, while, although, but, wct, pulau, that, agouti,
# Nearest to six: seven, five, four, eight, three, nine, one, dasyprocta,
# Nearest to been: reticulum, sidewise, pas, augustanus, romero, structures, macclannough, baghdad,
# Nearest to are: were, martians, complained, nicaragua, many, is, though, muslim,
# Nearest to some: many, all, these, other, different, each, several, grunds,
# Nearest to it: this, which, only, he, but, what, that, mindelo,
# Nearest to had: has, have, was, were, vertices, thus, glomerulosa, condensed,
# Nearest to also: knee, now, which, moreschi, yil, texans, ergosphere, termed,
# Nearest to b: d, e, r, m, rid, initiated, f, o,
#
#
# Average loss at step  82000 :  6.04370725477
# Average loss at step  84000 :  5.95199107146
# Average loss at step  86000 :  5.97414033496
# Average loss at step  88000 :  5.91381797361
# Average loss at step  90000 :  5.87877936554
# Average loss at step  92000 :  5.6125460912
# Average loss at step  94000 :  5.8267134527
# Average loss at step  96000 :  5.71764782596
# Average loss at step  98000 :  5.49459553266
# Average loss at step  100000 :  5.85431670785
# Nearest to called: microcebus, canaris, eritrea, praha, marek, megabats, gnats, where,
# Nearest to who: he, himself, grendel, him, working, by, oblivion, closer,
# Nearest to system: beautiful, cno, interceptor, agouti, cyc, financial, cloud, victoriae,
# Nearest to the: its, each, their, unassigned, another, fachhochschule, cebus, ursus,
# Nearest to would: will, could, may, should, must, can, thus, understood,
# Nearest to use: prat, reginae, agouti, fachhochschule, marek, ursus, dasyprocta, newly,
# Nearest to so: if, gly, hurrians, but, yakovlev, montferrat, agouti, makes,
# Nearest to however: while, but, although, where, that, wct, pulau, only,
# Nearest to six: seven, eight, four, five, three, nine, dasyprocta, ursus,
# Nearest to been: reticulum, sidewise, pas, romero, macclannough, augustanus, structures, tanzania,
# Nearest to are: were, martians, is, nicaragua, muslim, being, include, bonzos,
# Nearest to some: many, all, these, several, different, other, pseudalopex, both,
# Nearest to it: he, this, which, only, but, now, aethra, zuo,
# Nearest to had: has, have, was, were, after, would, when, but,
# Nearest to also: now, knee, often, which, moreschi, babysitter, termed, ergosphere,
# Nearest to b: d, e, r, maragall, UNKNOWN, m, initiated, rid,
#
#
# Average loss at step  102000 :  5.66042044532
# Average loss at step  104000 :  5.65023325133
# Average loss at step  106000 :  5.70996558022
# Average loss at step  108000 :  5.66862837517
# Average loss at step  110000 :  5.60408830512
# Average loss at step  112000 :  5.59441608977
# Average loss at step  114000 :  5.4130817858
# Average loss at step  116000 :  5.40142950928
# Average loss at step  118000 :  5.54181026387
# Average loss at step  120000 :  5.49126382709
# Nearest to called: microcebus, eritrea, praha, where, gnats, canaris, marek, wct,
# Nearest to who: he, grendel, him, himself, oblivion, working, closer, by,
# Nearest to system: beautiful, drinkordie, cno, method, source, systems, victoriae, agouti,
# Nearest to the: each, its, another, cebus, escuela, ursus, a, fachhochschule,
# Nearest to would: will, could, may, should, must, can, understood, thus,
# Nearest to use: prat, fachhochschule, reginae, agouti, marek, jhana, busan, abaddon,
# Nearest to so: if, gly, while, makes, when, but, gala, montferrat,
# Nearest to however: although, but, while, when, only, that, wct, where,
# Nearest to six: seven, four, five, eight, three, nine, dasyprocta, agouti,
# Nearest to been: reticulum, draupnir, sidewise, pas, augustanus, macclannough, romero, eleusinian,
# Nearest to are: were, martians, is, include, nicaragua, bonzos, muslim, being,
# Nearest to some: many, all, these, several, different, other, pseudalopex, both,
# Nearest to it: this, he, but, which, only, still, now, zuo,
# Nearest to had: has, have, was, having, holyangemon, after, were, cobbler,
# Nearest to also: now, knee, often, plugboard, which, moreschi, eurocents, hamlan,
# Nearest to b: d, r, e, f, c, lunda, m, walking,
#
#
# Average loss at step  122000 :  5.44413707042
# Average loss at step  124000 :  5.47724368024
# Average loss at step  126000 :  5.44459364009
# Average loss at step  128000 :  5.5062125026
# Average loss at step  130000 :  5.53211079955
# Average loss at step  132000 :  5.44592995298
# Average loss at step  134000 :  5.38805362654
# Average loss at step  136000 :  5.38857928526
# Average loss at step  138000 :  5.33109070456
# Average loss at step  140000 :  5.34963436246
# Nearest to called: microcebus, eritrea, considered, there, praha, gnats, marek, where,
# Nearest to who: he, grendel, himself, him, oblivion, closer, they, working,
# Nearest to system: beautiful, method, source, cno, drinkordie, systems, victoriae, interceptor,
# Nearest to the: its, another, each, their, any, zimri, sarandon, a,
# Nearest to would: will, could, may, should, must, can, cannot, to,
# Nearest to use: fachhochschule, prat, size, abaddon, sterbro, agouti, marek, busan,
# Nearest to so: gly, if, while, makes, neutronic, even, montferrat, abaddon,
# Nearest to however: although, but, while, when, though, only, because, that,
# Nearest to six: five, seven, eight, four, three, nine, two, ursus,
# Nearest to been: reticulum, draupnir, sidewise, macclannough, eleusinian, become, pas, resided,
# Nearest to are: were, martians, is, nicaragua, include, bryde, muslim, bonzos,
# Nearest to some: many, all, these, several, different, other, both, pseudalopex,
# Nearest to it: he, this, only, she, which, now, but, thought,
# Nearest to had: has, have, having, was, cobbler, were, holyangemon, after,
# Nearest to also: now, often, knee, which, plugboard, moreschi, preferred, ugric,
# Nearest to b: d, lunda, r, tr, corner, e, walking, leaders,
#
#
# Average loss at step  142000 :  5.5901262989
# Average loss at step  144000 :  5.26612549388
# Average loss at step  146000 :  5.25241644537
# Average loss at step  148000 :  5.26296027005
# Average loss at step  150000 :  5.18592042422
# Average loss at step  152000 :  5.13315936673
# Average loss at step  154000 :  5.25284741202
# Average loss at step  156000 :  5.31005287802
# Average loss at step  158000 :  5.20700581932
# Average loss at step  160000 :  5.27345944798
# Nearest to called: considered, UNKNOWN, microcebus, praha, eritrea, gnats, stadtbahn, wct,
# Nearest to who: grendel, he, him, oblivion, himself, closer, cupola, working,
# Nearest to system: beautiful, cno, method, source, systems, victoriae, drinkordie, interceptor,
# Nearest to the: another, each, its, any, a, their, fachhochschule, escuela,
# Nearest to would: will, could, may, must, should, can, cannot, might,
# Nearest to use: fachhochschule, form, cause, weight, abaddon, size, sterbro, busan,
# Nearest to so: if, gly, while, usually, then, agouti, even, makes,
# Nearest to however: although, but, while, though, when, only, because, still,
# Nearest to six: seven, five, four, three, eight, nine, one, zero,
# Nearest to been: reticulum, draupnir, become, sidewise, eleusinian, macclannough, kornfeld, consorts,
# Nearest to are: were, nicaragua, martians, include, is, muslim, being, complained,
# Nearest to some: many, all, several, these, both, various, different, pseudalopex,
# Nearest to it: he, this, only, which, she, still, zuo, but,
# Nearest to had: has, have, having, was, cobbler, risc, spacecraft, holyangemon,
# Nearest to also: now, often, knee, plugboard, entangling, ugric, moreschi, shuja,
# Nearest to b: d, r, f, e, tr, walking, lunda, p,
#
#
# Average loss at step  162000 :  5.25632023919
# Average loss at step  164000 :  5.16792455471
# Average loss at step  166000 :  5.04184285057
# Average loss at step  168000 :  5.15237857342
# Average loss at step  170000 :  5.09759774446
# Average loss at step  172000 :  5.15970058846
# Average loss at step  174000 :  5.15592842734
# Average loss at step  176000 :  5.11108287191
# Average loss at step  178000 :  5.07776010811
# Average loss at step  180000 :  5.19232344604
# Nearest to called: considered, zlotych, microcebus, praha, eritrea, but, where, abbates,
# Nearest to who: grendel, himself, he, him, already, closer, metaphor, cupola,
# Nearest to system: systems, beautiful, source, method, cno, victoriae, drinkordie, herrings,
# Nearest to the: another, each, its, prespa, any, airplanes, fachhochschule, instead,
# Nearest to would: will, could, must, should, may, can, cannot, might,
# Nearest to use: form, cause, fachhochschule, size, weight, ragnhild, abaddon, development,
# Nearest to so: if, gly, even, usually, but, thus, agouti, while,
# Nearest to however: but, although, while, though, when, because, still, agouti,
# Nearest to six: seven, four, three, eight, five, zero, nine, one,
# Nearest to been: reticulum, become, draupnir, eleusinian, kornfeld, kotor, macclannough, sidewise,
# Nearest to are: were, is, martians, include, complained, nicaragua, muslim, bonzos,
# Nearest to some: many, all, these, several, different, various, both, other,
# Nearest to it: only, this, he, she, which, just, but, still,
# Nearest to had: has, have, having, was, holyangemon, landsmannschaft, gadgets, gru,
# Nearest to also: now, often, knee, plugboard, ugric, still, which, sometimes,
# Nearest to b: d, r, f, c, p, e, m, l,
#
#
# Average loss at step  182000 :  5.06925069511
# Average loss at step  184000 :  5.18341551673
# Average loss at step  186000 :  4.97659627414
# Average loss at step  188000 :  5.03992404282
# Average loss at step  190000 :  5.09956837177
# Average loss at step  192000 :  5.09739447451
# Average loss at step  194000 :  5.04417432272
# Average loss at step  196000 :  4.9963241787
# Average loss at step  198000 :  5.03187161231
# Average loss at step  200000 :  4.87275943875
# Nearest to called: considered, zlotych, praha, microcebus, now, eritrea, abbates, stadtbahn,
# Nearest to who: himself, grendel, already, cupola, he, oblivion, mr, metaphor,
# Nearest to system: beautiful, source, method, systems, cno, victoriae, drinkordie, vittorini,
# Nearest to the: its, another, zimri, cebus, negating, labialized, bde, altenberg,
# Nearest to would: will, could, should, must, may, can, cannot, might,
# Nearest to use: form, fachhochschule, cause, weight, size, development, ragnhild, discontinuous,
# Nearest to so: gly, even, usually, thus, if, risotto, abaddon, once,
# Nearest to however: although, but, while, though, because, when, neutronic, pulau,
# Nearest to six: seven, five, eight, four, three, hyi, agouti, bde,
# Nearest to been: become, reticulum, draupnir, eleusinian, consorts, kornfeld, resided, macclannough,
# Nearest to are: were, martians, complained, include, being, is, muslim, many,
# Nearest to some: many, all, these, several, different, both, various, those,
# Nearest to it: he, she, but, only, now, just, they, zuo,
# Nearest to had: has, have, having, was, gadgets, holyangemon, banteng, newtonian,
# Nearest to also: now, often, knee, plugboard, ugric, which, heterozygous, still,
# Nearest to b: d, r, lunda, leaders, tr, walking, asylees, kannauj,

# %%
def save_words_embeddings(embeddings, word_counts):
    
    np.save('embeddings.npy', embeddings)
    
    words = [x[0] for x in word_counts]
    np.save('words.npy', words)
    
save_words_embeddings(final_embeddings, word_counts)

# %% [markdown]
# ### Visualize the embeddings

# %%
import matplotlib.pyplot as plt

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'

    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)

        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)
    plt.show(filename)

# %%
from sklearn.manifold import TSNE
NUM_PLOT_POINTS = 500

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')

low_dim_embs = tsne.fit_transform(final_embeddings[:NUM_PLOT_POINTS, :])

labels = [reversed_dictionary[i] for i in xrange(NUM_PLOT_POINTS)]

# %%
plot_with_labels(low_dim_embs, labels)
